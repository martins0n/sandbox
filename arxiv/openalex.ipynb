# %%
concepts = {
    "Time Series": "https://api.openalex.org/works?filter=concepts.id:C151406439",
    "Probabilistic forecasting": "https://api.openalex.org/works?filter=concepts.id:C122282355",
    "Demand forecasting": "https://api.openalex.org/works?filter=concepts.id:C193809577"
}
unparsed_works_ids = {
    "Time Series": "C151406439",
    "Probabilistic forecasting": "C122282355",
    "Demand forecasting": "C193809577"
}
unparsed_works_dict = {
    "Time Series": [],
    "Probabilistic forecasting": [],
    "Demand forecasting": []
}

# %%
import requests

import seaborn as sns
import pandas as pd
pd.set_option('display.max_colwidth', 300)

# %%
CONCEPT_ID = "C122282355"
YEAR = 2021
cited_by_count = 10

# %%
TEMPLATE = "https://api.openalex.org/works?filter=concepts.id:{concept_id},publication_year:{publication_year},cited_by_count:>{cited_by_count}&per-page=50&page={page_id}"

# %%
responce = requests.get(
    TEMPLATE.format(
        concept_id=CONCEPT_ID,
        publication_year=YEAR,
        cited_by_count=cited_by_count
    )
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_31003/739847580.py in <module>
#       1 responce = requests.get(
# ----> 2     TEMPLATE.format(
#       3         concept_id=CONCEPT_ID,
#       4         publication_year=YEAR,
#       5         cited_by_count=cited_by_count
#
# KeyError: 'page_id'

# %%
from typing import Any, List, Optional

from pydantic import BaseModel

class Author(BaseModel):
    id: str
    display_name: str
    orcid: Optional[str]

class Institution(BaseModel):
    id: Optional[str]
    display_name: Optional[str]
    country_code: Optional[str]

class Authorship(BaseModel):
    author: Author
    institutions: List[Institution]
    author_position: str

class Concept(BaseModel):
    id: str
    display_name: str
    score: Optional[float]
    level: int
    wikidata: str

class Work(BaseModel):
    id: str
    display_name: str
    publication_date: str
    relevance_score: Optional[float]
    authorships: List[Authorship]
    concepts: List[Concept]
    cited_by_count: int
    publication_year: int
    cited_by_api_url: List[str]
    doi: Optional[str]
    referenced_works: List[str]
    related_works: List[str]
    abstract_inverted_index: Optional[dict]

# %%
for concept_id in unparsed_works_ids:
    page_id = 1
    while True:
        template = TEMPLATE.format(concept_id=unparsed_works_ids[concept_id], publication_year=YEAR, cited_by_count=cited_by_count, page_id=page_id)
        print(template)
        responce = requests.get(template).json()
        unparsed_works_dict[concept_id] += responce["results"]
        print(len(responce["results"]))
        if len(responce["results"]) == 0:
            break
        else:
            page_id += 1
# Out:
# https://api.openalex.org/works?filter=concepts.id:C151406439,publication_year:2021,cited_by_count:>10&per-page=50&page=1
# 50
# https://api.openalex.org/works?filter=concepts.id:C151406439,publication_year:2021,cited_by_count:>10&per-page=50&page=2
# 50
# https://api.openalex.org/works?filter=concepts.id:C151406439,publication_year:2021,cited_by_count:>10&per-page=50&page=3
# 12
# https://api.openalex.org/works?filter=concepts.id:C151406439,publication_year:2021,cited_by_count:>10&per-page=50&page=4
# 0
# https://api.openalex.org/works?filter=concepts.id:C122282355,publication_year:2021,cited_by_count:>10&per-page=50&page=1
# 23
# https://api.openalex.org/works?filter=concepts.id:C122282355,publication_year:2021,cited_by_count:>10&per-page=50&page=2
# 0
# https://api.openalex.org/works?filter=concepts.id:C193809577,publication_year:2021,cited_by_count:>10&per-page=50&page=1
# 22
# https://api.openalex.org/works?filter=concepts.id:C193809577,publication_year:2021,cited_by_count:>10&per-page=50&page=2
# 0

# %%
parsed_works = dict()
for concept_id in unparsed_works_dict:
    parsed_works[concept_id] = [Work(**i) for i in unparsed_works_dict[concept_id]]

# %%
for i in parsed_works:
    print(f"{i}: {len(unparsed_works_dict[i])}")
# Out:
# Time Series: 112
# Probabilistic forecasting: 23
# Demand forecasting: 22

# %%
parsed_works_with_index = dict()

# %%
import tqdm

# %%
for concept_id in parsed_works:
    for work in tqdm.tqdm(parsed_works[concept_id]):
        if work.id not in parsed_works_with_index:
            url_api = work.id[:8] + "api." + work.id[8:]
            parsed_works_with_index[work.id] = Work(**requests.get(url_api).json())
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 112/112 [16:11<00:00,  8.67s/it]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 23/23 [02:05<00:00,  5.46s/it]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 22/22 [02:13<00:00,  6.05s/it]

# %%
df = pd.DataFrame([val.dict() for i, val in parsed_works_with_index.items()])

# %%
df.head()
# Out:
#                                  id  \
# 0  https://openalex.org/W3167954679
# 1  https://openalex.org/W3015378124
# 2  https://openalex.org/W2888954762
# 3  https://openalex.org/W1580469992
# 4  https://openalex.org/W3191026187
#
#                                                                               display_name  \
# 0                                A guide to state-space modeling of ecological time series
# 1                                                       Adversarial Attacks on Time Series
# 2            Hidden Markov Models for Time Series: An Introduction Using R, Second Edition
# 3  Forecasting Financial Markets Using Neural Networks An Analysis of Methods and Accuracy
# 4                               Time Series Data Augmentation for Deep Learning: A Survey.
#
#   publication_date relevance_score  \
# 0       2021-11-01            None
# 1       2021-10-01            None
# 2       2021-09-30            None
# 3       2021-08-16            None
# 4       2021-08-09            None
#
#                                                                                                                                                                                                                                                                                                    authorships  \
# 0  [{'author': {'id': 'https://openalex.org/A2398706194', 'display_name': 'Marie Auger-Méthé', 'orcid': 'https://orcid.org/0000-0003-3550-4930'}, 'institutions': [{'id': 'https://openalex.org/I141945490', 'display_name': 'University of British Columbia', 'country_code': 'CA'}], 'author_position': '...
# 1  [{'author': {'id': 'https://openalex.org/A2229077872', 'display_name': 'Fazle Karim', 'orcid': 'https://orcid.org/0000-0002-7998-8546'}, 'institutions': [{'id': 'https://openalex.org/I39422238', 'display_name': 'University of Illinois at Chicago', 'country_code': 'US'}], 'author_position': 'firs...
# 2  [{'author': {'id': 'https://openalex.org/A2213794972', 'display_name': 'Walter Zucchini', 'orcid': None}, 'institutions': [], 'author_position': 'first'}, {'author': {'id': 'https://openalex.org/A2085390103', 'display_name': 'Iain L. MacDonald', 'orcid': 'https://orcid.org/0000-0001-6433-2707'},...
# 3                                                                                                                                                [{'author': {'id': 'https://openalex.org/A287426837', 'display_name': 'Jason E. Kutsurelis', 'orcid': None}, 'institutions': [], 'author_position': 'first'}]
# 4  [{'author': {'id': 'https://openalex.org/A2141035074', 'display_name': 'Qingsong Wen', 'orcid': None}, 'institutions': [{'id': 'https://openalex.org/I45928872', 'display_name': 'Alibaba Group', 'country_code': 'CN'}], 'author_position': 'first'}, {'author': {'id': 'https://openalex.org/A32107449...
#
#                                                                                                                                                                                                                                                                                                       concepts  \
# 0  [{'id': 'https://openalex.org/C18903297', 'display_name': 'Ecology', 'score': 0.50035, 'level': 1, 'wikidata': 'https://www.wikidata.org/wiki/Q7150'}, {'id': 'https://openalex.org/C143724316', 'display_name': 'Series (stratigraphy)', 'score': 0.475543, 'level': 2, 'wikidata': 'https://www.wikida...
# 1  [{'id': 'https://openalex.org/C41008148', 'display_name': 'Computer science', 'score': 0.724428, 'level': 0, 'wikidata': 'https://www.wikidata.org/wiki/Q21198'}, {'id': 'https://openalex.org/C37736160', 'display_name': 'Adversarial system', 'score': 0.641261, 'level': 2, 'wikidata': 'https://www...
# 2  [{'id': 'https://openalex.org/C143724316', 'display_name': 'Series (stratigraphy)', 'score': 0.617789, 'level': 2, 'wikidata': 'https://www.wikidata.org/wiki/Q312468'}, {'id': 'https://openalex.org/C41008148', 'display_name': 'Computer science', 'score': 0.555022, 'level': 0, 'wikidata': 'https:...
# 3  [{'id': 'https://openalex.org/C50644808', 'display_name': 'Artificial neural network', 'score': 0.575266, 'level': 2, 'wikidata': 'https://www.wikidata.org/wiki/Q192776'}, {'id': 'https://openalex.org/C41008148', 'display_name': 'Computer science', 'score': 0.447679, 'level': 0, 'wikidata': 'htt...
# 4  [{'id': 'https://openalex.org/C41008148', 'display_name': 'Computer science', 'score': 0.745651, 'level': 0, 'wikidata': 'https://www.wikidata.org/wiki/Q21198'}, {'id': 'https://openalex.org/C108583219', 'display_name': 'Deep learning', 'score': 0.558097, 'level': 2, 'wikidata': 'https://www.wik...
#
#    cited_by_count  publication_year  \
# 0              12              2021
# 1              24              2021
# 2              28              2021
# 3              39              2021
# 4              14              2021
#
#                                             cited_by_api_url  \
# 0  [https://api.openalex.org/works?filter=cites:W3167954679]
# 1  [https://api.openalex.org/works?filter=cites:W3015378124]
# 2  [https://api.openalex.org/works?filter=cites:W2888954762]
# 3  [https://api.openalex.org/works?filter=cites:W1580469992]
# 4  [https://api.openalex.org/works?filter=cites:W3191026187]
#
#                                           doi  \
# 0            https://doi.org/10.1002/ecm.1470
# 1  https://doi.org/10.1109/tpami.2020.2986319
# 2                                        None
# 3                                        None
# 4     https://doi.org/10.24963/ijcai.2021/631
#
#                                                                                                                                                                                                                                                                                               referenced_works  \
# 0  [https://openalex.org/W1965175390, https://openalex.org/W2035636354, https://openalex.org/W2098767549, https://openalex.org/W2124078578, https://openalex.org/W1976253647, https://openalex.org/W2049228615, https://openalex.org/W2139606141, https://openalex.org/W2155702894, https://openalex.org/W2...
# 1  [https://openalex.org/W2551393996, https://openalex.org/W2754051771, https://openalex.org/W2039260438, https://openalex.org/W2402972623, https://openalex.org/W2962718684, https://openalex.org/W2787615497, https://openalex.org/W2892035503, https://openalex.org/W2964253222, https://openalex.org/W2...
# 2                                                                                                                                                                                                                                                                                                           []
# 3  [https://openalex.org/W1669375728, https://openalex.org/W2124776405, https://openalex.org/W1526844615, https://openalex.org/W1589922412, https://openalex.org/W1521061969, https://openalex.org/W1492620359, https://openalex.org/W1582318580, https://openalex.org/W1587239851, https://openalex.org/W1...
# 4                                                                                                                                                                                                                                                                                                           []
#
#                                                                                                                                                                                                                                                                                                  related_works  \
# 0  [https://openalex.org/W3004555295, https://openalex.org/W2884241775, https://openalex.org/W3138627724, https://openalex.org/W3109498698, https://openalex.org/W2499390929, https://openalex.org/W2914721251, https://openalex.org/W2416768583, https://openalex.org/W3097013233, https://openalex.org/W2...
# 1  [https://openalex.org/W2460937040, https://openalex.org/W3103075267, https://openalex.org/W2963857521, https://openalex.org/W2556782416, https://openalex.org/W2243397390, https://openalex.org/W3131164743, https://openalex.org/W3100485466, https://openalex.org/W2975486888, https://openalex.org/W2...
# 2  [https://openalex.org/W2999872301, https://openalex.org/W2341959691, https://openalex.org/W3119426301, https://openalex.org/W2485874359, https://openalex.org/W2617619904, https://openalex.org/W2547039301, https://openalex.org/W138349194, https://openalex.org/W1882651929, https://openalex.org/W42...
# 3  [https://openalex.org/W2573444250, https://openalex.org/W2275717981, https://openalex.org/W2104846125, https://openalex.org/W2139997280, https://openalex.org/W2183616920, https://openalex.org/W3113190877, https://openalex.org/W3194426173, https://openalex.org/W1995456904, https://openalex.org/W2...
# 4  [https://openalex.org/W2496879562, https://openalex.org/W3033757695, https://openalex.org/W2975792400, https://openalex.org/W2965323200, https://openalex.org/W3044203329, https://openalex.org/W2922386288, https://openalex.org/W3176197839, https://openalex.org/W2515550864, https://openalex.org/W3...
#
#                                                                                                                                                                                                                                                                                        abstract_inverted_index
# 0  {'State–space': [0], 'models': [1, 15, 193], '(SSMs)': [2], 'are': [3, 16, 29, 40, 44, 169], 'an': [4, 239, 259], 'important': [5], 'modeling': [6], 'framework': [7], 'for': [8, 163, 228], 'analyzing': [9], 'ecological': [10, 37, 53, 110, 232], 'time': [11], 'series.': [12], 'These': [13], 'hier...
# 1  {'Time': [0], 'series': [1, 54, 80, 172], 'classification': [2, 55, 62, 81, 173], 'models': [3, 121, 174], 'have': [4], 'been': [5, 18], 'garnering': [6], 'significant': [7], 'importance': [8], 'in': [9], 'the': [10, 61, 73, 76, 137, 158], 'research': [11, 16], 'community.': [12], 'However,': [1...
# 2                                                                                                                                                                                                                                                                                                         None
# 3  {'Abstract': [0], ':': [1], 'This': [2, 83, 101], 'research': [3, 65, 102], 'examines': [4], 'and': [5, 69, 108, 127], 'analyzes': [6], 'the': [7, 44, 47, 67, 80, 87, 104, 110, 138, 148, 158, 164], 'use': [8, 165], 'of': [9, 25, 46, 71, 106, 112, 122, 132, 166], 'neural': [10, 18, 61, 73, 114, 1...
# 4  {'Deep': [0], 'learning': [1, 80], 'performs': [2], 'remarkably': [3], 'well': [4], 'on': [5, 21, 82], 'many': [6, 36], 'time': [7, 38, 49, 83, 97, 134], 'series': [8, 39, 50, 84, 135], 'analysis': [9], 'tasks': [10, 132], 'recently.': [11], 'The': [12], 'superior': [13], 'performance': [14], 'o...

# %%
def index_to_abstract(index):
    if index is None:
        return
    max_len = -1
    for i, val in index.items():
        max_len = max(max_len, max(val))
    
    abstract_list = ["" for i in range(max_len+1)]
    for i, val in index.items():
        for j in val:
            abstract_list[j] = i
    
    return " ".join(abstract_list).lower()

# %%
df["summary"] = df.abstract_inverted_index.apply(index_to_abstract)
df["title"] = df["display_name"]

# %% [markdown]
# ## Top 20 papers in Time Series in 2021 year

# %%
df.sort_values(by="cited_by_count", ascending=False)[["title", "cited_by_count"]].head(20)
# Out:
#                                                                                                                                                       title  \
# 100                                                             Recurrent Neural Networks for Time Series Forecasting: Current status and future directions
# 33                                                                                                    Time-series forecasting with deep learning: a survey.
# 95                               A novel displacement prediction method using gated recurrent unit model with time series analysis in the Erdaohe landslide
# 127  Computationally efficient forecasting procedures for Kuhn-Tucker consumer demand model systems: Application to residential energy consumption analysis
# 71                                                                                                     Deep Learning for Time Series Forecasting: A Survey.
# 77                    LPG consumption and environmental Kuznets curve hypothesis in South Asia: a time-series ARDL analysis with multiple structural breaks
# 3                                                                   Forecasting Financial Markets Using Neural Networks An Analysis of Methods and Accuracy
# 65   A combined forecasting system based on statistical method, artificial neural networks, and deep learning methods for short-term wind speed forecasting
# 16                                                                                 Spatial prediction of COVID-19 epidemic using ARIMA techniques in India.
# 9                                                             An empirical survey of data augmentation for time series classification with neural networks.
# 60                                                                                 Deep-Convolution-Based LSTM Network for Remaining Useful Life Prediction
# 124                                            Exploring impacts of on-demand ridesplitting on mobility via real-world ridesourcing data and questionnaires
# 120                                                                      Hierarchical Probabilistic Forecasting of Electricity Demand With Smart Meter Data
# 48                                       Can CO2 emissions and energy consumption determine the economic performance of South Korea? A time series analysis
# 110                                                                                 Two-phase deep learning model for short-term wind direction forecasting
# 7                                                                                             Monitoring the SARS Epidemic in China: A Time Series Analysis
# 98                                                  A novel stacked generalization ensemble-based hybrid LGBM-XGB-MLP model for Short-Term Load Forecasting
# 41                                                          LSTM-MSNet: Leveraging Forecasts on Sets of Related Time Series With Multiple Seasonal Patterns
# 13                                           GLC_FCS30: global land-cover product with fine classification system at 30 m using time-series Landsat imagery
# 68                                                                  Short-term wind speed forecasting using recurrent neural networks with error correction
#
#      cited_by_count
# 100             147
# 33               57
# 95               54
# 127              53
# 71               43
# 77               40
# 3                39
# 65               38
# 16               37
# 9                37
# 60               37
# 124              36
# 120              36
# 48               36
# 110              36
# 7                33
# 98               32
# 41               31
# 13               31
# 68               29

# %%
from utils import pipeline_normalize
from nltk import ngrams

# %%
df = (
    df
    .pipe(lambda x: x.assign(parsed_title = x.title.apply(pipeline_normalize)))
    .pipe(lambda x: x.assign(parsed_summary = x.summary.apply(pipeline_normalize)))
    .pipe(lambda x: x.assign(parsed_title_2gram = x.parsed_title.apply(lambda x: list(ngrams(x, 2)))))
    .pipe(lambda x: x.assign(parsed_summary_2gram = x.parsed_summary.apply(lambda x: list(ngrams(x, 2)))))
)

# %%
df.parsed_summary_2gram.explode().value_counts().head(20)
# Out:
# (time, seri)         169
# (neural, network)     72
# (wind, speed)         63
# (short, term)         62
# (deep, learn)         40
# (long, short)         35
# (term, memori)        34
# (machin, learn)       26
# (speed, forecast)     26
# (forecast, model)     26
# (propos, method)      24
# (predict, model)      23
# (seri, data)          23
# (propos, model)       22
# (result, show)        20
# (data, set)           20
# (real, world)         19
# (land, cover)         19
# (seri, forecast)      18
# (wind, power)         17
# Name: parsed_summary_2gram, dtype: int64

# %%
df.parsed_title_2gram.explode().value_counts().head(20)
# Out:
# (time, seri)            62
# (short, term)           23
# (neural, network)       23
# (deep, learn)           17
# (seri, forecast)        12
# (wind, speed)           12
# (speed, forecast)       11
# (forecast, model)        9
# (term, wind)             8
# (machin, learn)          7
# (recurr, neural)         7
# (seri, analysi)          6
# (term, memori)           6
# (long, short)            6
# (seri, data)             5
# (model, short)           5
# (learn, approach)        4
# (autoregress, model)     4
# (model, use)             4
# (artifici, neural)       4
# Name: parsed_title_2gram, dtype: int64

# %% [markdown]
# ## Top 20 papers in Time Series in 2021 year with `neural-network` bigram

# %%
(
    df
    .pipe(lambda x: x[lambda y: y.parsed_summary_2gram.apply(lambda z: ("neural", "network") in z)])
    .sort_values(by="cited_by_count", ascending=False)[["title", "cited_by_count"]]
)
# Out:
#                                                                                                                                                              title  \
# 100                                                                    Recurrent Neural Networks for Time Series Forecasting: Current status and future directions
# 71                                                                                                            Deep Learning for Time Series Forecasting: A Survey.
# 3                                                                          Forecasting Financial Markets Using Neural Networks An Analysis of Methods and Accuracy
# 60                                                                                        Deep-Convolution-Based LSTM Network for Remaining Useful Life Prediction
# 9                                                                    An empirical survey of data augmentation for time series classification with neural networks.
# 52                                                     A time series-based statistical approach for outbreak spread forecasting: Application of COVID-19 in Greece
# 68                                                                         Short-term wind speed forecasting using recurrent neural networks with error correction
# 22                                     Multi-hour and multi-site air quality index forecasting in Beijing using CNN, LSTM, CNN-LSTM, and spatiotemporal clustering
# 108  Evaluating the performances of several artificial intelligence methods in forecasting daily streamflow time series for sustainable water resources management
# 64                                                                              An Experimental Review on Deep Learning Architectures for Time Series Forecasting.
# 89              Hybrid artificial neural network and cooperation search algorithm for nonlinear river flow time series forecasting in humid and semi-humid regions
# 27                                                                Reservoir Computing Approaches for Representation and Classification of Multivariate Time Series
# 102                                                      Machine learning for pore-water pressure time-series prediction: Application of recurrent neural networks
# 5                                                                         Stock Price Prediction Using Convolutional Neural Networks on a Multivariate Time Series
# 40                       Application of hybrid model based on empirical mode decomposition, novel recurrent neural networks and the ARIMA to wind speed prediction
# 121                                                                                       Advanced Deep Learning Approach for Probabilistic Wind Speed Forecasting
# 97                                                                         Remaining Useful Life Prognosis Based on Ensemble Long Short-Term Memory Neural Network
# 136                                                                                                                    Retail sales forecasting with meta-learning
# 80                                                                  High temporal resolution rainfall–runoff modeling using long-short-term-memory (LSTM) networks
# 35                    Super ensemble learning for daily streamflow forecasting: large-scale demonstration and comparison with multiple machine learning algorithms
# 86                                                                            Effective crude oil price forecasting using new text-based and big-data-driven model
# 62                          Parallel computing and swarm intelligence based artificial intelligence model for multi-step-ahead hydrological time series prediction
# 17                                               An artificial neural network-based forecasting model of energy-related time series for electrical grid management
# 46                                                                                 Nonlinear Neural Network Based Forecasting Model for Predicting COVID-19 Cases.
# 83                                                                  An improved SPEI drought forecasting approach using the long short-term memory neural network.
# 18                                                                      Rainfall forecasting model using machine learning methods: Case study Terengganu, Malaysia
# 57                                                                   Anomaly Detection of Time Series With Smoothness-Inducing Sequential Variational Auto-Encoder
# 74                                                                      A combined method for short-term traffic flow prediction based on recurrent neural network
# 4                                                                                                       Time Series Data Augmentation for Deep Learning: A Survey.
# 15                                                                                                Cash flow prediction: MLP and LSTM compared to ARIMA and Prophet
# 113                               A deep learning-based evolutionary model for short-term wind speed forecasting: A case study of the Lillgrund offshore wind farm
# 67                                                           Analysis of different RNN autoencoder variants for time series classification and machine prognostics
# 44                              Statistical modeling of monthly streamflow using time series and artificial neural network models: Hindiya Barrage as a case study
# 84                                                                                                Deep Temporal Convolution Network for Time Series Classification
# 88                                                          Time series forecasting of COVID-19 transmission in Asia Pacific countries using deep neural networks.
# 34                                                               A Novel Hybrid Short-Term Load Forecasting Method of Smart Grid Using MLR and LSTM Neural Network
# 94                                                                            Implementing transfer learning across different datasets for time series forecasting
# 105                                                                                       Prediction model for stock price trend based on recurrent neural network
# 112                                                     Deep-Learning-Based Probabilistic Forecasting of Electric Vehicle Charging Load With a Novel Queuing Model
# 125                                                Multimodal Data Guided Spatial Feature Fusion and Grouping Strategy for E-Commerce Commodity Demand Forecasting
# 26                                                                  Outlier-Resistant Remote State Estimation for Recurrent Neural Networks With Mixed Time-Delays
# 45                                                                     A permutation entropy-based EMD–ANN forecasting ensemble approach for wind speed prediction
# 14                                    Hybrid forecasting system based on data area division and deep learning neural network for short-term wind speed forecasting
# 76       Ensemble empirical mode decomposition and long short-term memory neural network for multi-step predictions of time series signals in nuclear power plants
# 79                                                       A Deep Learning algorithm for modeling and forecasting of COVID-19 in five worst affected states of India
#
#      cited_by_count
# 100             147
# 71               43
# 3                39
# 60               37
# 9                37
# 52               29
# 68               29
# 22               27
# 108              26
# 64               25
# 89               22
# 27               21
# 102              20
# 5                20
# 40               20
# 121              19
# 97               19
# 136              19
# 80               18
# 35               18
# 86               17
# 62               17
# 17               17
# 46               16
# 83               16
# 18               15
# 57               15
# 74               15
# 4                14
# 15               14
# 113              14
# 67               14
# 44               14
# 84               14
# 88               13
# 34               13
# 94               13
# 105              13
# 112              13
# 125              13
# 26               12
# 45               12
# 14               12
# 76               11
# 79               11
